# %%
import pandas as pd

# %%
#import the data
mimic_path='/Users/jieche/Desktop/machine learning/mimic-iv-2.2/'

# %% [markdown]
# microbiology events

# %%
import pandas as pd

# specify the path to the CSV file

# read in the microbiologyevents table from the CSV file
microbiologyevents = pd.read_csv(mimic_path+'hosp/microbiologyevents', compression='gzip', sep='|', usecols=[
                                 'subject_id', 'hadm_id', 'charttime', 'chartdate'])

# display the first few rows of the DataFrame
print(microbiologyevents.head())

# %% [markdown]
# prescriptions

# %%
# read in prescriptions table from CSV file
prescriptions = pd.read_csv(mimic_path + 'hosp/prescriptions.csv.gz', compression='gzip')
# Out:
# /var/folders/ck/8r_z2td51y379bxk8krf4ss00000gn/T/ipykernel_55910/466490456.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   prescriptions = pd.read_csv(mimic_path + 'hosp/prescriptions.csv.gz', compression='gzip')

# %%
prescriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15416708 entries, 0 to 15416707
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   subject_id         int64
#  1   hadm_id            int64
#  2   pharmacy_id        int64
#  3   poe_id             object
#  4   poe_seq            float64
#  5   order_provider_id  object
#  6   starttime          object
#  7   stoptime           object
#  8   drug_type          object
#  9   drug               object
#  10  formulary_drug_cd  object
#  11  gsn                object
#  12  ndc                float64
#  13  prod_strength      object
#  14  form_rx            object
#  15  dose_val_rx        object
#  16  dose_unit_rx       object
#  17  form_val_disp      object
#  18  form_unit_disp     object
#  19  doses_per_24_hrs   float64
#  20  route              object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 2.4+ GB

# %%
prescriptions.head()
# Out:
#    subject_id   hadm_id  pharmacy_id       poe_id  poe_seq order_provider_id  \
# 0    10000032  22595853     11700683  10000032-34     34.0            P76JEQ
# 1    10000032  22595853     14779570  10000032-22     22.0            P76JEQ
# 2    10000032  22595853     19796602  10000032-50     50.0            P260SK
# 3    10000032  22595853     20256254  10000032-32     32.0            P76JEQ
# 4    10000032  22595853     28781051  10000032-27     27.0            P76JEQ
#
#              starttime             stoptime drug_type  \
# 0  2180-05-07 01:00:00  2180-05-07 22:00:00      MAIN
# 1  2180-05-07 00:00:00  2180-05-07 22:00:00      MAIN
# 2  2180-05-08 08:00:00  2180-05-07 22:00:00      MAIN
# 3  2180-05-07 01:00:00  2180-05-07 22:00:00      MAIN
# 4  2180-05-07 00:00:00  2180-05-07 22:00:00      MAIN
#
#                           drug  ...     gsn           ndc  \
# 0                Acetaminophen  ...  004490  9.041989e+08
# 1  Sodium Chloride 0.9%  Flush  ...     NaN  0.000000e+00
# 2                   Furosemide  ...  008209  5.107901e+10
# 3                  Raltegravir  ...  063231  6.022761e+06
# 4                      Heparin  ...  006549  6.332303e+10
#
#                prod_strength form_rx dose_val_rx dose_unit_rx form_val_disp  \
# 0               500mg Tablet     NaN         500           mg             1
# 1              10 mL Syringe     NaN           3           mL           0.3
# 2                40mg Tablet     NaN          40           mg             1
# 3              400 mg Tablet     NaN         400           mg             1
# 4  5000 Units / mL- 1mL Vial     NaN        5000         UNIT             1
#
#   form_unit_disp doses_per_24_hrs  route
# 0            TAB              NaN  PO/NG
# 1            SYR              3.0     IV
# 2            TAB              1.0  PO/NG
# 3            TAB              2.0     PO
# 4             mL              3.0     SC
#
# [5 rows x 21 columns]

# %%
# filter for antibiotics of interest
antibiotics = ['002542', '002543', '007371', '008873', '008877', '008879', '008880', '008935', '008941',
               '008942', '008943', '008944', '008983', '008984', '008990', '008991', '008992', '008995', '008996',
               '008998', '009043', '009046', '009065', '009066', '009136', '009137', '009162', '009164', '009165',
               '009171', '009182', '009189', '009213', '009214', '009218', '009219', '009221', '009226', '009227',
               '009235', '009242', '009263', '009273', '009284', '009298', '009299', '009310', '009322', '009323',
               '009326', '009327', '009339', '009346', '009351', '009354', '009362', '009394', '009395', '009396',
               '009509', '009510', '009511', '009544', '009585', '009591', '009592', '009630', '013023', '013645',
               '013723', '013724', '013725', '014182', '014500', '015979', '016368', '016373', '016408', '016931',
               '016932', '016949', '018636', '018637', '018766', '019283', '021187', '021205', '021735', '021871',
               '023372', '023989', '024095', '024194', '024668', '025080', '026721', '027252', '027465', '027470',
               '029325', '029927', '029928', '037042', '039551', '039806', '040819', '041798', '043350', '043879',
               '044143', '045131', '045132', '046771', '047797', '048077', '048262', '048266', '048292', '049835',
               '050442', '050443', '051932', '052050', '060365', '066295', '067471']

abx_prescriptions = prescriptions[prescriptions['gsn'].isin(antibiotics)]

# %%
abx_prescriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 361881 entries, 14 to 15400915
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   subject_id         361881 non-null  int64
#  1   hadm_id            361881 non-null  int64
#  2   pharmacy_id        361881 non-null  int64
#  3   poe_id             354355 non-null  object
#  4   poe_seq            354355 non-null  float64
#  5   order_provider_id  360687 non-null  object
#  6   starttime          356885 non-null  object
#  7   stoptime           357097 non-null  object
#  8   drug_type          361881 non-null  object
#  9   drug               361881 non-null  object
#  10  formulary_drug_cd  361735 non-null  object
#  11  gsn                361881 non-null  object
#  12  ndc                361737 non-null  float64
#  13  prod_strength      361881 non-null  object
#  14  form_rx            162 non-null     object
#  15  dose_val_rx        361881 non-null  object
#  16  dose_unit_rx       361881 non-null  object
#  17  form_val_disp      361881 non-null  object
#  18  form_unit_disp     361881 non-null  object
#  19  doses_per_24_hrs   352948 non-null  float64
#  20  route              361881 non-null  object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 60.7+ MB

# %%
abx_prescriptions.head()
# Out:
#      subject_id   hadm_id  pharmacy_id        poe_id  poe_seq  \
# 14     10000032  22841357      7922025   10000032-92     92.0
# 25     10000032  22841357     53555857   10000032-94     94.0
# 47     10000032  25742920     71423977  10000032-244    244.0
# 60     10000032  29079034     19164513  10000032-178    178.0
# 190    10000764  27897940     67322733   10000764-50     50.0
#
#     order_provider_id            starttime             stoptime drug_type  \
# 14             P8971Q  2180-06-26 23:00:00  2180-06-27 23:00:00      MAIN
# 25             P8971Q  2180-06-26 23:00:00  2180-06-27 23:00:00      MAIN
# 47             P76JEQ  2180-08-06 03:00:00  2180-08-07 22:00:00      MAIN
# 60             P20F7Z  2180-07-23 20:00:00  2180-07-25 22:00:00      MAIN
# 190            P43T74  2132-10-15 20:00:00  2132-10-19 00:00:00      MAIN
#
#                             drug  ...     gsn           ndc  prod_strength  \
# 14                     Rifaximin  ...  066295  6.564903e+10   550mg Tablet
# 25     Sulfameth/Trimethoprim DS  ...  009396  9.042726e+08      DS Tablet
# 47                     Rifaximin  ...  066295  6.564903e+10   550mg Tablet
# 60                     Rifaximin  ...  066295  6.564903e+10   550mg Tablet
# 190  Amoxicillin-Clavulanic Acid  ...  008992  6.668510e+10   500mg Tablet
#
#     form_rx dose_val_rx dose_unit_rx form_val_disp form_unit_disp  \
# 14      NaN         550           mg             1            TAB
# 25      NaN           1          TAB             1            TAB
# 47      NaN         550           mg             1            TAB
# 60      NaN         550           mg             1            TAB
# 190     NaN         500           mg             1            TAB
#
#     doses_per_24_hrs  route
# 14               2.0  PO/NG
# 25               1.0  PO/NG
# 47               2.0  PO/NG
# 60               2.0  PO/NG
# 190              3.0  PO/NG
#
# [5 rows x 21 columns]

# %%
# save to CSV
abx_prescriptions.to_csv('abx.csv', index=False)

# %%
import pandas as pd

# read in d_items table from CSV file
d_items = pd.read_csv(mimic_path + 'icu/d_items.csv.gz', compression='gzip')

# %%
# filter for label associated with itemid 225814
label = d_items.loc[d_items['itemid'] == 227726, 'label']

# print label
print(label)
# Out:
# 2405    AVA Line Tip Cultured
# Name: label, dtype: object
